# %%
# %pylab inline
import rinobot_plugin as bot
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = bot.loadfile('./examples/data.txt')
x = data[:, 0]
y = data[:, 1]

xyyy = np.vstack((x, y, y + 10, y + 20)).T
xyxy = np.vstack((x, y, x, y + 20)).T
binsize=10

# %%
def rebin(data, binsize, x_string=None, algo='average'):
    col_num = data.shape[1]
    new_data = np.zeros((data.shape[0]// binsize, col_num))

    indices = bot.build_index(data, x_string, None)
    mask = np.ones(a.shape,dtype=bool) #np.ones_like(a,dtype=bool)
    mask[indices] = False

    x = data[mask]
    y = data[~mask]
    
    for index, data_row in enumerate(data.T):
        new_row = np.array([])
        for i in range(0, len(data_row) // binsize):
            sublist = data_row[i*binsize:(i*binsize)+binsize]

            if algo == 'average':
                new_row = np.append(new_row, sublist.mean())

        new_data[:, index] = new_row
    return new_data

new_data = rebin(xyyy, 5)

plt.plot(xyyy[:, 0], xyyy[:, 1:])
plt.plot(new_data[:, 0], new_data[:, 1:])

plt.xlim([160, 185])
# Out:
# (160, 185)
